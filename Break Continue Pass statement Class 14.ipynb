# %%
# what is unconditional jump statements

# what is Break statement
# The break statement is used to terminate the for or while loop.
# We should use break statement along with the if statement
# When encountered ,Its comes out of a loop
# syntax of Break

# Break in for loop

for i in range(10):
    if i>=5:
        break
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# break in while loop

i=1
while i<10:
    print(i)
    if i==5:
        break
    else:
        i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# what is Continue statement
# Continue statement is used in looping to skip some statements.
# We should use continue statement along with the if statement.
# When continue statement encounters, the execution will go to the starting of the loop.
# The statements below continue statement will n't be executed if the given condition becomes true
# syntax of Continue

# Continue in for loop
a="happyday"
for value in a:
    if value=="a":
        continue
    else:
        print(value)
# Out:
# h
# p
# p
# y
# d
# y

# %%
for value in "happy learning":
    
    if value=="n":
         continue
    else:
        print(value)
# Out:
# h
# a
# p
# p
# y
#
# l
# e
# a
# r
# i
# g

# %%
for i in range(1,10):    ## odd numbers
    if(i%2==0):
        continue
    else:   
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
print(1%2)
# Out:
# 1

# %%
for i in range(1,10):    ## even numbers 
    if(i%2!=0):
        continue
    else:  
        print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
for i in range(10):
    if(i==5):
        continue
    print(i)


# The continue statement in python is used to bring the program control to the beginning of the loop.
# The continue statement skips the remaining lines of code inside the loop and starts with the next iteration.
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
# what is pass statement
# syntax
# example 1

print("Hi")

for i in range(1,11):
    pass
           
print("hai buddy")
print("how are you?")    
print("PROGRAMME TERMINATED")
# Out:
# Hi
# hai buddy
# how are you?
# PROGRAMME TERMINATED

# %%
# example 2
age=33
if age<=35:
    pass
     
else:
    print("Not Eligible")
    
    
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# example 3

i=1
while i<=10:
    if(i==5):
        pass
    else:
        print(i)
        i=i+1

# %%
for i in range(10):
    if (i==5):
        pass
        
    else:
        print(i)
        
print("program terminated")

# The statement is used as a placeholder for future code.
# When the pass statement is excuted,nothing happens but you avoid getting an error when empty code is not allowed.
# Empty code is not allowed in loops,function definitions,or in if statements.
