# %%
#Check if a number is positive
num = 5
print(num > 0)
# Out:
# True

# %%
#Compare two numbers
a = 10
b = 20
print(a < b)
# Out:
# True

# %%
#Check if two strings are equal
name1 = "python"
name2 = "python"
print(name1 == name2)
# Out:
# True

# %%
#Check if a number is even (boolean result)
num = 12
print(num % 2 == 0)
# Out:
# True

# %%
#Boolean AND operator
a = True
b = False
print(a and b)
# Out:
# False

# %%
#Boolean OR operator
x = False
y = True
print(x or y)
# Out:
# True

# %%
#Boolean NOT operator
flag = True
print(not flag)
# Out:
# False

# %%
#Check if age is eligible for voting (True/False)
age = 17
print(age >= 18)
# Out:
# False

# %%
#Check if a number lies between 1 and 10
n = 7
print(n > 1 and n < 10)
# Out:
# True

# %%
#Check if username is not empty
username = "Divya"
print(username != "")
# Out:
# True

# %%
#Check string conditions
name = input("Enter your name: ")
print(name.isalpha())
# Out:
# Enter your name:  r
# True

# %%
#Age eligibility for voting
age = int(input("Enter your age: "))
print(age >= 18)
# Out:
# Enter your age:  78
# True

# %%
#Username validation
username = input("Enter username: ")
print(username != "")
# Out:
# Enter username:
# False
