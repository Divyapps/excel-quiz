# %%
# string concatenation 

value1="python"
value2="programming"

print(value1,value2)
# Out:
# python programming

# %%
value1="python"
value2="java"
result=value1 * value2
print(result)
# Out:
# pythonpythonpythonpython

# %%
name="vishnu "

print(name * 3)
# Out:
# vishnu vishnu vishnu

# %%
# printing the string statements

x = "Welcome to"
y = "world"

print("helllo!" + x + "Python" + y)
# Out:
# helllo!Welcome toPythonworld

# %%
# string indexing
# Positive Indexing

a="Hello"

print(a[-1])
print(a[-2])
# Out:
# o
# l

# %%
## Nagative Indexing
print(a[-1])
print(a[-5])
# Out:
# o
# H

# %%
# string slicing
## Positive slicing

## Slicing   formula (start:stop-1:step)

a="hellovishnu" 

print(a[0:4])
# Out:
# hell

# %%
# negative slicing

a="hello"
a[:-2]
# Out:
# 'hel'

# %%
#step argument

a="happylearning"


a[::-1]
# Out:
# 'gninraelyppah'

# %%
## String Built in Methods

# %%
# capitalize()
    
a="placement point solution"

print(a.capitalize())
# Out:
# Placement point solution

# %%
age="my age is 26"

print(age.capitalize())
# Out:
# My age is 26

# %%
# count()

b="welcome to placement to point"

print(b.count(""))
# Out:
# 30

# %%
# islower() and lower()


c="python for starters"
d="python for Starters"
e="python for starters"

print(c.islower())
print(d.islower())
print(e.islower())
# Out:
# True
# False
# True

# %%
c="pYthon for sTARters"
d="PYTHon for stArtERS"
e="PYTHON FOR STARTERS"

print(c.lower())
print(d.lower())
print(e.lower())
# Out:
# python for starters
# python for starters
# python for starters

# %%
# isupper() and upper()

c="pYthon for sTARters"
d="PYTHon for stArtERS"
e="PYTHON FOR STARTERS123"
print(c.isupper())
print(d.isupper())
print(e.isupper())
# Out:
# False
# False
# True

# %%
# UPPER()

c="pYthon for sTARters"
d="PYTHon for stArtERS"
e="python for starters"
print(c.upper())
print(d.upper())
print(e.upper())
# Out:
# PYTHON FOR STARTERS
# PYTHON FOR STARTERS
# PYTHON FOR STARTERS

# %%
# swapcase()

f="PYthon for startERS"

print(f.swapcase())
# Out:
# pyTHON FOR STARTers

# %%
# istitle() and title()

g="welcome to placement point solutions"

print(g.title())
# Out:
# Welcome To Placement Point Solutions

# %%
# istitle()

g="welcome to placement Point"

print(g.istitle())
# Out:
# False

# %%
# startswith()

var="hey how are you??"

print(var.startswith("you"))
# Out:
# False

# %%
# endswith()

var="hi how are you"

print(var.endswith("are"))
# Out:
# False

# %%
# isnumeric()

num= "12345"

print(num.isnumeric())

num1="123x"

print(num1.isnumeric())
# Out:
# True
# False

# %%
#isalpha()

alp="hello"
print(alp.isalpha())

alp2="hello10"
print(alp2.isalpha())
# Out:
# True
# False

# %%
# isalnum()

abc="123python"
print(abc.isalnum())

alphabet="python"
print(alphabet.isalnum())

num="123"
print(num.isalnum())
# Out:
# True
# True
# True

# %%
# find()

txt="welcome to PPS"

print(txt.find("o"))
print(txt.find("S"))
# Out:
# 4
# 13

# %%
# index()

txt="welcome to PPS"

print(txt.index("e"))
print(txt.index(" y"))
# Out:
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       3 txt="welcome to PPS"
#       5 print(txt.index("e"))
# ----> 6 print(txt.index(" y"))
#
# ValueError: substring not found

# %%
# replace()

a="i love dogs"

print(a.replace("i","we"))
# Out:
# we love dogs

# %%
b="i love dogs,i love flowers,i love parrots"

print(b.replace("i","we",3))
# Out:
# we love dogs,we love flowers,we love parrots

# %%
# strip()

word="@#$python@$$"


print(word.strip("#@$ @ "))
# Out:
# python

# %%
# ljust(), rjust() and center()

word="python"

print(word.ljust(10, '*'))
# Out:
# python****

# %%
word="python"
print(word.rjust(7,'$'))
# Out:
# $python

# %%
word="python"

print(word.center(15,'@'))
# Out:
# @@@@@python@@@@
