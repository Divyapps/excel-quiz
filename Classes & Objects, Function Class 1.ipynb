# %%
# What is OOPS ?(Object Oriented Programming System)
# In Python, object-oriented Programming (OOPs) is a programming paradigm that uses objects and classes in programming.
# OOPs, concepts in python, aim to implement real-world entities like inheritance, polymorphisms, encapsulation, etc., in the programming.
# OOPS Topics 
# 1.Classes and Objects
# 2.Constructor 
# 3.Inheritance 
# 4.Polymorphism
# 5.Encapsulation (Data Abstraction)

# %%
# Classes and Objects in Python
# Python is an object oriented programming language.
# Almost everything in Python is an object, with its properties and methods.
# A Class is like an object constructor, or a "blueprint" for creating objects.

#syntax;

class person():
    
# Class: A class is a blueprint or template for declaring and creating objects.
# Out:
#   Cell In[1], line 10
#     # Class: A class is a blueprint or template for declaring and creating objects.
#                                                                                        ^
# _IncompleteInputError: incomplete input

# %%
#class with print

class person():
    print("hyyy")
oj.person()
# Out:
# hyyy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 5
#       3 class person():
#       4     print("hyyy")
# ----> 5 oj.person()
#
# AttributeError: 'Car' object has no attribute 'person'

# %%
class Car:
    def __init__(self, make, model, year):  #parameter passing
        self.make = make
        self.model = model
        self.year = year

    def display_info(self):
         print(f"{self.make} {self.model} {self.year}")

make=int(input())
mode=int(input())
year=int(input())
oj=Car(make,mode,year)
oj.display_info()

# %%
#class with variable

class person():
    print("hiii")
    a=10
    print(a)
# Out:
# hiii
# 10

# %%
class person():
    print("hai")
    a=10
    
print(a)
# Out:
# hai
# 10

# %%
#creating object

class fun():
    def add(self):
        a=10
        b=5
        print(a+b)

obj=fun()
obj.add()

# Object: An object is an instance of class that allows programmers to use variables and methods from inside the class.
# Out:
# 15

# %%
# class and object
class pd():
    print("hai")
    a=10
obj=pd()
print(obj.a)
print(type(obj))
# Out:
# hai
# 10
# <class '__main__.pd'>

# %%
class person():
    a=10
    b=20
obj=person()
print(obj.a)
obj1=person()
print(obj1.b)

# class simple definition class is blueprint of the oblect
# object simple definition instand of the class
# Out:
# 10
# 20

# %%
# what is function
# A function is a block of code which only runs when it is called.
# You can pass data, known as parameters, into a function.
# A function can return data as a result.

# syntax
# In Python a function is defined using the def keyword:

def greeting():
    print("hello i am from function")

# %%
# sample code

def greeting():
    print("hello.. i am from function")
    
greeting()
# Out:
# hello.. i am from function

# %%
def greeting():
    print("hello.. i am from function")
    print("happy learning")
greeting()
# Out:
# hello.. i am from function
# happy learning

# %%
def greeting():
    print("hello.. i am from function")
    print("happy learning")
    
greeting()
greeting()
# Out:
# hello.. i am from function
# happy learning
# hello.. i am from function
# happy learning

# %%
def add():
    print(3+5)
def mul():
    print(3*5)
    
    
mul()
add()
# Out:
# 15
# 8

# %%
def test():
    print("i am from test")
test()
# Out:
# i am from test

# %%
def fun():
    print("Hi Computer I am Pasupathi..,,!! ")
fun()
# Out:
# Hi Computer I am Pasupathi..,,!!

# %%
def fun(name):
    print("Hi Computer I am",name)
    
fun("Karthick")
# Out:
# Hi Computer I am Karthick

# %%
def fun(name):
    print("Hi Computer I am",name)
    
name=input("Enter your name:")    
fun(name)
# Out:
# Enter your name: MANI
# Hi Computer I am MANI

# %%
def fun(name="Pasupathi"):
    print("Hi Computer I am",name)
fun()
# Out:
# Hi Computer I am Pasupathi

# %%
obj1 = Calc

obj1.sub(38,12)
# Out:
# 26

# %%
import numpy as np
