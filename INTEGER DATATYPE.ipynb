# %%
#Write a program to store two integers and print their sum.
# Your task: change the numbers and print the sum
a = 12
b = 8
print(a + b)
# Out:
# 20

# %%
#Take two integer inputs from the user and multiply them.
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
print(x * y)
# Out:
# Enter first number:  23
# Enter second number:  89
# 2047

# %%
#Check if a given number is even or odd.
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  67
# Odd

# %%
#Write a program to find the square of an integer.
n = 7
print(n * n)
# Out:
# 49

# %%
#Store three integers and find their average.
a = 10
b = 20
c = 30
avg = (a + b + c) / 3
print(avg)
# Out:
# 20.0

# %%
#Write a program to swap two integer variables.
a = 5
b = 10

a, b = b, a
print(a, b)
# Out:
# 10 5

# %%
#Print the largest of three integers.
a = 10
b = 25
c = 15

print("Largest number is:", max(a, b, c))
# Out:
# Largest number is: 25

# %%
#Write a program to convert minutes into seconds using integers.
minutes = 5
seconds = minutes * 60
print(seconds)
# Out:
# 300

# %%
#Add two negative integers.
x = -4
y = -6
print(x + y)
# Out:
# -10

# %%
#Use integers in a simple profit calculation.
cost_price = 100
selling_price = 150
profit = selling_price - cost_price
print(profit)

# %%
#sum()
print(sum([1, 2, 3]))
# Out:
# 6

# %%
#range()          Generates a range of integers:
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#pow() – Power function
print(pow(2, 3))
# Out:
# 8

# %%
#max() – Largest number
print(max(10, 20, 5, 8))
# Out:
# 20

# %%
#min() – Smallest number
print(min(10, 20, 5, 8))
# Out:
# 5
