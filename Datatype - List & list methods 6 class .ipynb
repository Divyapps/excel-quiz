# %%
# what is list?

name="sarathi"
gender="Male"
height=5.5

# %%
a=[]
print(a)
print(type(a))
# Out:
# []
# <class 'list'>

# %%
# list indexing.

detail=["SARATHI",'Male',28,5.6,1+3j]

print(detail)
print(detail[-3])
# Out:
# ['SARATHI', 'Male', 28, 5.6, (1+3j)]
# 28

# %%
a="python"
print(a[0])
# Out:
# p

# %%
# indexing- access

num=[10,"PYTHON",60]

print(num[1][0:4])
# Out:
# PYTH

# %%
values = input("Enter the sentance:").split()
print(values)
# Out:
# Enter the sentance: hii, welcome to tech world guys
# ['hii,', 'welcome', 'to', 'tech', 'world', 'guys']

# %%
# indexing- modify

names=["sakthi","ganesh","suvetha",50]

names[3]= "Suriya"
print(names)
# Out:
# ['sakthi', 'ganesh', 'suvetha', 'Suriya']

# %%
# indexing- deletion

names=["sakthi","ganesh","suvetha"]

del names[1]
print(names)
# Out:
# ['sakthi', 'suvetha']

# %%
# list slicing #
# slicing- access

number=[10,20,30,40,50]
print(number[0:4])
print(number[1:3])
print(number[::-1])
# Out:
# [10, 20, 30, 40]
# [20, 30]
# [50, 40, 30, 20, 10]

# %%
number[:4]
# Out:
# [10, 20, 30, 40]

# %%
number[2:]
# Out:
# [30, 40, 50]

# %%
# reversing the list

num=[10,20,30,40,50,60,70,80,90]

print(num[::-1])
# Out:
# [90, 80, 70, 60, 50, 40, 30, 20, 10]

# %%
#list modify ### slicing formula (start,stop-1,step)

num=[10,20,30,40,50,60,70,80,90]

num[0:3]=[1,2,3]

print(num)
# Out:
# [1, 2, 3, 40, 50, 60, 70, 80, 90]

# %%
num=[10,20,30,40,50,60,70,80,90]

num[:8:2]=[1,1,1,1]
print(num)
# Out:
# [1, 20, 1, 40, 1, 60, 1, 80, 90]

# %% [markdown]
# # num=[10,20,30,40,50,60,70,80,90]
# num[::2]=[1,1,1,1]
# num

# %%
# slicing- deletion

num=[10,20,30,40,50,60,70,80,90]
del num[0:4]
print(num)
# Out:
# [50, 60, 70, 80, 90]

# %%
num=[10,20,30,40,50,60,70,80,90]
del num[0::2]
print(num)
# Out:
# [20, 40, 60, 80]

# %%
# basic operations in list - len()

l1=[1,2,3,4]      
l2=[1,3,2,["hello",4],8]

l3=[1,2,3,"hello",5]

print(len(l1))
print(len(l2))
print(len(l3))
# Out:
# 4
# 5
# 5

# %%
# basic operations - concatenation

l1=[1,2,3]
l2=[4,5,6]

print(l1+l2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# basic operations - repetition

l1=[1,2,3]
l2=[4,5,6]

print(l1*l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       3 l1=[1,2,3]
#       4 l2=[4,5,6]
# ----> 6 print(l1*l2)
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
# Built in methods in List

# append () extend () -string value 

l1=["blue","yellow","black"]


l1.append("white")

print(l1)

l1.extend("white")

print(l1)
# Out:
# ['blue', 'yellow', 'black', 'white']
# ['blue', 'yellow', 'black', 'white', 'w', 'h', 'i', 't', 'e']

# %%
# append () extend () -numeric value

l1=["blue","yellow","black"]
l1.append(20)
print(l1)

l2=["blue","yellow","black"]
l2.extend([20])
print(l2)
# Out:
# ['blue', 'yellow', 'black', 20]
# ['blue', 'yellow', 'black', 20]

# %%
# append () extend () -list

a=["yellow","black"]
b=["pink","white",12]

a.append(b)
print(a)
a=["yellow","black"]
b=["pink","white",123]
a.extend(b)
print(a)
# Out:
# ['yellow', 'black', ['pink', 'white', 12]]
# ['yellow', 'black', 'pink', 'white', 123]

# %%
# append () extend () -numeric list

a=[1,2]
a.append([3,4])
print(a)
a=[1,2]
a.extend([3,4])
print(a)
# Out:
# [1, 2, [3, 4]]
# [1, 2, 3, 4]

# %%
# insert()

l1=["red","orange","yellow"]

l1.insert(1,"blue")
print(l1)
# Out:
# ['red', 'blue', 'orange', 'yellow']

# %%
# pop()

l1=["red","orange","yellow","BLUE","RED"]
l1.pop()
print(l1)
# Out:
# ['red', 'orange', 'yellow', 'BLUE']

# %%
l1=["red","orange","yellow"]
l1.pop(1)
print(l1)
# Out:
# ['red', 'yellow']

# %%
# remove()

l1=["red","orange","yellow","yellow"]

l1.remove("red")
print(l1)
# Out:
# ['orange', 'yellow', 'yellow']

# %%
# clear()

l1=["red","yellow","orange","yellow"]
l1.clear()
print(l1)
# Out:
# []

# %%
# del()

l1=["red","yellow","orange","yellow"]

print(l1)

del l1

print(l1)
# Out:
# ['red', 'yellow', 'orange', 'yellow']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       5 print(l1)
#       7 del l1
# ----> 9 print(l1)
#
# NameError: name 'l1' is not defined

# %%
# index()

l1=["yellow","orange","yellow","yellow"]

l1.index("yellow")
# Out:
# 0

# %%
l1=["red","yellow","orange","yellow"]

print(l1.count("yellow"))
# Out:
# 2

# %%
# count()

l1=[1,2,3,4,5,6,1,1]

print(l1.count(1))
# Out:
# 3

# %%
# copy()

list1=["red","yellow","orange","blue","white"]

list2=list1.copy()


print(list2)
# Out:
# ['red', 'yellow', 'orange', 'blue', 'white']

# %%
# sort()

l1=["red","yellow","orange","blue","white"]
l1.sort()
print(l1)

l2=[2,6,8,3,5,1,4,7,1]
print(sorted(l2))
# Out:
# ['blue', 'orange', 'red', 'white', 'yellow']
# [1, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
# reverse()

l1=["red","yellow","orange","yellow"]
l1.reverse()
print(l1)
# Out:
# ['yellow', 'orange', 'yellow', 'red']

# %%
# List Unpacking

a=["python","java","sql"]

x,y,z=a
print(x)
print(y)
print(z)
# Out:
# python
# java
# sql

# %%
# List Packing
b=["Prasanna","Male",3.8,4.7,4.9,5.0,5.8,6.7]

*name,gender,height=b

print(name)
print(gender)
print(height)
# Out:
# ['Prasanna', 'Male', 3.8, 4.7, 4.9, 5.0]
# 5.8
# 6.7
