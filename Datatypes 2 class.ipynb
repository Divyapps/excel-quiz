# %% [markdown]
# ###### example:
#
# name = "Sarath", 24,'python' # string
#
# age = 24   # integer
# height = 5.6 # float
# compl=1+2j # complex

# %%
name = "Sarath", 24,'python' # string
age = "45"
# age = 24   # integer
height = 5.6 # float
compl=1+2j # complex

# %%
age
type(age)
# Out:
# str

# %%
name = input("Enter your name : ")
print("hi,my name is " + name)
# Out:
# Enter your name :  meena
# hi,my name is meena

# %%
n1 =  int(input("Enter the 1st number :"))
n2 =  int(input("Enter the 2nd number :"))
sum = n1+n2
print(sum)
# Out:
# Enter the 1st number : 56
# Enter the 2nd number : 44
# 100

# %%
type(n1)
# Out:
# int

# %% [markdown]
# # Data types in python.
#
# numeric
#
# string
#
# list
#
# tuples
#
# dictionary
#
# set
#
# Boolean

# %%
# input() function.

#name=input("Enter Your Name:")
#age=input("Enter your age:")

name = int(input("Enter your name"))
print(name)
print(type(name))
# Out:
# Enter your name 56
# 56
# <class 'int'>

# %%
# type() function

value = 1
print(type(value))
# Out:
# <class 'int'>

# %%
a = 25
print(type(a))
# Out:
# <class 'int'>

# %%
x = 15
print(x)
x = x + 10
print(x)
# Out:
# 15
# 25

# %%
age  = int(input("ENTER YOUR AGE :"))
print(age)
print(type(age))
# Out:
# ENTER YOUR AGE : 56
# 56
# <class 'int'>

# %%
#  datatype convertions.

age=int(input("enter your age:"))
# Out:
# enter your age: 10

# %%
a=10
a
# Out:
# 10

# %%
a="muthu kumar"
a
# Out:
# 'muthu kumar'

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age=age+3
print(age)
# Out:
# 13

# %%
height= float(input("enter your height:"))
print(height)
print(type(height))
# Out:
# enter your height: 456.87
# 456.87
# <class 'float'>

# %%
print(type(height))
# Out:
# <class 'float'>

# %%
# printing variables.
name = "vishnu"
age = 28
height = 5.7
print(name)
print(age)
print(height)
# Out:
# vishnu
# 28
# 5.7

# %%
print(name,age,height)
# Out:
# Surya 25 165.5

# %%
print("Your name is : ", name)
print("your age is:",age)
print("your height is:",height)
# Out:
# Your name is :  45
# your age is: 30
# your height is: 78.0

# %%
name = input("enter your name :")
age = int(input("enter your age :"))
height = float(input("enter your height :"))
# Out:
# enter your name : Santhosh
# enter your age : 26
# enter your height : 6.5

# %%
print("Your name is",name," your age is ",age," your height is ",height)
# Out:
# Your name is Santhosh  your age is  26  your height is  6.5

# %%
print(f"Your name is {name} your age is {age} your height is {height}")
# Out:
# Your name is Santhosh your age is 26 your height is 6.5

# %%
value=input("Enter your name:")
print("Welcome to tech world!",value)
# Out:
# Enter your name: Mani
# Welcome to tech world! Mani
