# %%
# what is Dictionary
# creating empty dictionary

d={}
print(type(d))
# Out:
# <class 'dict'>

# %%
d1={"name":"vishal","age":26,45:35}

print(d1)
# Out:
# {'name': 'vishal', 'age': 26, 45: 35}

# %%
lis=[12,34,56,45]
    
print(lis)

d1={"name":"sakthi","city":"chennai",
    "age":20}
print(d1)
# Out:
# [12, 34, 56, 45]
# {'name': 'sakthi', 'city': 'chennai', 'age': 20}

# %%
a=(1,2,3,4)
  
print(list(a))
# Out:
# [1, 2, 3, 4]

# %%
# list as dictionary

a=["name","age","gender"]
b=["vishal",28,"male"]

c=dict(zip(a,b))

print(c)
# Out:
# {'name': 'vishal', 'age': 28, 'gender': 'male'}

# %%
# tuple as dictionary

a=("name","age","height")
b=("sakthi",20,5.7)
c=dict(zip(a,b))
print(c)
# Out:
# {'name': 'sakthi', 'age': 20, 'height': 5.7}

# %%
a=["name","age"]
b=("sakthi",20)

c=dict(zip(a,b))
print(c)
# Out:
# {'name': 'sakthi', 'age': 20}

# %%
a=["name","age"]
b=("sakthi",20)
c=dict(zip(b,a))
print(c)
# Out:
# {'sakthi': 'name', 20: 'age'}

# %%
# dict() function

name1=dict(name="vishal",age=20,roll="analyst")

print(name1)
# Out:
# {'name': 'vishal', 'age': 20, 'roll': 'analyst'}

# %%
# basic operations -len

l1={'name': 'sakthi', 'age': 20}
print(len(l1))
# Out:
# 2

# %%
# basic operations -concatenation

c1={'name': 'sakthi'}
c2={'age': 20}
c1+c2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       3 c1={'name': 'sakthi'}
#       4 c2={'age': 20}
# ----> 5 c1+c2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
# basic operations -reptition

c1={'name':'sakthi'}
c1*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 # basic operations -reptition
#       3 c1={'name':'sakthi'}
# ----> 4 c1*3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
c=[1,2,3]
b=[4,5,6]
print(b*3)
# Out:
# [4, 5, 6, 4, 5, 6, 4, 5, 6]

# %%
# accessing dict elements

var={'name': 'vishal', 'age': 20}

print(var["age"])
# Out:
# 20

# %%
var={'name': 'sakthi','age':23}

var["name"]
# Out:
# 'sakthi'

# %%
# modifying dict elements

mod={'name': 'sakthi', 'age': 20}

mod["name"]="vishnu"
print(mod)
# Out:
# {'name': 'vishnu', 'age': 20}

# %%
# deleting dict elements and enire dictionary

mod={'name': 'sakthi', 'age': 20}

del mod["name"]
print(mod)
# Out:
# {'age': 20}

# %%
a={'name': 'sakthi', 'age': 20}
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 a={'name': 'sakthi', 'age': 20}
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
# built in methods

# %%
# items()

d={"name":"sakthi","age":67,"height":4.5}
d.items()
# Out:
# dict_items([('name', 'sakthi'), ('age', 67), ('height', 4.5)])

# %%
# keys()

d={"name":"sakthi","age":67,"height":4.5}
d.keys()
# Out:
# dict_keys(['name', 'age', 'height'])

# %%
# values()

d={"name":"sakthi","age":67,"height":4.5}
d.values()
# Out:
# dict_values(['sakthi', 67, 4.5])

# %%
# access- get()

d={"name":"sakthi","age":67,"height":4.5}
d.get("name")
# Out:
# 'sakthi'

# %%
d={"name":"sakthi","age":67,"height":4.5}
d.get("address",1)
# Out:
# 1

# %%
# update()

d={"name":"sakthi","age":67,"height":4.5}

d.update(height=6.0)

print(d)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 6.0}

# %%
d1={"name":"sakthi","age":67,"height":4.5}

d2={"address":"null"}


d1.update(d2)

print(d1)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 4.5, 'address': 'null'}

# %%
d1={"name":"sakthi","age":67,"height":4.5}
d2={"address":"nil"}


d1.update(d2,FATHERNAME="SHIVA",mothername="santhi",lastname="pooja")

print(d1)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 4.5, 'address': 'nil', 'FATHERNAME': 'SHIVA', 'mothername': 'santhi', 'lastname': 'pooja'}

# %%
# copy()

d1={"name":"sakthi","age":67,"height":4.5}

d2=d1.copy()

print(d2)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 4.5}

# %%
# fromkeys

key=["sarathi","bharath","kannan"]

value=0

dict1={}

result=dict1.fromkeys(key,value)
print(result)
# Out:
# {'sarathi': (0, 100, 10), 'bharath': (0, 100, 10), 'kannan': (0, 100, 10)}

# %%
# setdefault()

d={"name":"sakthi","age":67,"height":4.5}

d.setdefault("fname","shiva")
print(d)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 4.5, 'fname': 'shiva'}

# %%
d={"name":"sakthi","age":67,"height":4.5}

d.setdefault("age1",68)

print(d)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 4.5, 'age1': 68}

# %%
#Update

d={"name":"sakthi","age":67,"height":4.5}
d.update(age=90)
print(d)
# Out:
# {'name': 'sakthi', 'age': 90, 'height': 4.5}

# %%
d1={"name":"sakthi","age":67,"height":4.5}
d2={"address":"nil","work":"IIT"}

d1.update(d2,company="Google")
print(d1)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 4.5, 'address': 'nil', 'work': 'IIT', 'company': 'Google'}

# %%
# pop()

d={"name":"sakthi","age":67,"height":4.5}
d.pop("name")
print(d)
# Out:
# {'age': 67, 'height': 4.5}

# %%
# popitem()

d={"name":"sakthi","age":67,"height":4.5,"company":"pps"}
d.popitem()
print(d)
# Out:
# {'name': 'sakthi', 'age': 67, 'height': 4.5}

# %%
# del()

d={"name":"sakthi","age":67,"height":4.5}
del d["name"]
print(d)
# Out:
# {'age': 67, 'height': 4.5}

# %%
d={"name":"sakthi","age":67,"height":4.5}
del d
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 d={"name":"sakthi","age":67,"height":4.5}
#       2 del d
# ----> 3 print(d)
#
# NameError: name 'd' is not defined

# %%
# clear()

d={"name":"sakthi","age":67,"height":4.5}
d.clear()
print(d)
# Out:
# {}
