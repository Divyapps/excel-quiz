# %%
# what is boolean datatype

# %%
# assigning boolean values.

a = True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
b=False
print(b)
print(type(b))
# Out:
# False
# <class 'bool'>

# %%
# ex: type bool.
a=12
b=10

print(a<b)
# Out:
# False

# %%
# basic operations.
print(True + True)
# Out:
# 2

# %%
10 + True
# Out:
# 11

# %%
11.56 +True
# Out:
# 12.56

# %%
print(True+False)
# Out:
# 1

# %%
print(False+False)
# Out:
# 0

# %%
print(True * 15)
# Out:
# 15

# %%
print(True//True)
# Out:
# 1

# %%
print(True/True)
# Out:
# 1.0

# %%
# passing int - bool
#int(2.3)
a=(float(12))
print(a)
# Out:
# 12.0

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
print(bool(1))
print(bool(0))
# Out:
# True
# False

# %%
# float -  bool
bool(0)
# Out:
# False

# %%
s=1

bool(s)
# Out:
# True

# %%
# string - bool
bool("python")
# Out:
# True

# %%
# list - bool
bool([5,7])
# Out:
# True

# %%
# tuple - bool
bool((1,2,3))
# Out:
# True

# %%
# dict - bool
bool({})
# Out:
# False

# %%
# set - bool
bool({1,2,3})
# Out:
# True

# %%
# bool - false
bool("")
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool(["python"])
# Out:
# True

# %%
bool({})
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
# None Type 
a=10
print(a)
# Out:
# 10

# %%
d=9
a=None

b=5
c=3

print(d)
print(b)
# Out:
# 9
# 5

# %%
c=None
b=5
print(b)
# Out:
# 5

# %%
bool(None)
# Out:
# False
